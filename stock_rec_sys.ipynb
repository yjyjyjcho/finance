# %%
import numpy as np
import pandas as pd

# pd.set_option('display.max_row', 500)
# pd.set_option('display.max_columns', 100)
trd = pd.read_csv('trade_train.csv')
sts = pd.read_csv('stocks.csv', encoding = 'utf-8')

trd.rename(columns = {'Unnamed: 0': 'index'}, inplace = True)

print(trd.head(10))
print(trd.columns)
print('\n')
print(sts.head(10))
print(sts.columns)
# Out:
#    index    기준년월   그룹번호  그룹내고객수     종목번호 그룹내_매수여부 그룹내_매도여부  매수고객수  매도고객수  \
# 0      0  201907  MAD01     288  A000660        Y        Y      7     17
# 1      1  201907  MAD01     288  A001820        Y        Y      3      4
# 2      2  201907  MAD01     288  A004020        Y        Y      3      3
# 3      3  201907  MAD01     288  A005380        Y        Y      4      3
# 4      4  201907  MAD01     288  A005930        Y        Y     13     19
# 5      5  201907  MAD01     288  A005935        Y        Y      5      6
# 6      6  201907  MAD01     288  A006400        Y        Y      6      5
# 7      7  201907  MAD01     288  A008770        Y        N      4      0
# 8      8  201907  MAD01     288  A009150        Y        Y     14     10
# 9      9  201907  MAD01     288  A034220        Y        Y      3      3
#
#    평균매수수량  평균매도수량  매수가격_중앙값  매도가격_중앙값
# 0      19     234     74800     78500
# 1     533     154     47385     46700
# 2     409     528     41411     40000
# ...

# %%
# gr_trd = trd.groupby(trd['그룹번호'])
# gr_trd.head(2)
print(trd.dtypes)
print('\n')
print(trd.info())
print('\n')
print(trd.describe())
# Out:
# index        int64
# 기준년월         int64
# 그룹번호        object
# 그룹내고객수       int64
# 종목번호        object
# 그룹내_매수여부    object
# 그룹내_매도여부    object
# 매수고객수        int64
# 매도고객수        int64
# 평균매수수량       int64
# 평균매도수량       int64
# 매수가격_중앙값     int64
# 매도가격_중앙값     int64
# dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30200 entries, 0 to 30199
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     30200 non-null  int64
#  1   기준년월      30200 non-null  int64
#  2   그룹번호      30200 non-null  object
#  3   그룹내고객수    30200 non-null  int64
#  4   종목번호      30200 non-null  object
#  5   그룹내_매수여부  30200 non-null  object
#  6   그룹내_매도여부  30200 non-null  object
#  7   매수고객수     30200 non-null  int64
#  8   매도고객수     30200 non-null  int64
#  9   평균매수수량    30200 non-null  int64
#  10  평균매도수량    30200 non-null  int64
#  11  매수가격_중앙값  30200 non-null  int64
#  12  매도가격_중앙값  30200 non-null  int64
# ...

# %%
print('sts.dtypes' '\n', sts.dtypes)
print('\n')
print('sts.info' '\n', sts.info())
print('\n')
print('sts.describe' '\n', sts.describe())
# Out:
# sts.dtypes
#  index             int64
# 기준일자              int64
# 종목번호             object
# 종목명              object
# 20년7월TOP3대상여부    object
# 시장구분             object
# 표준산업구분코드_대분류     object
# 표준산업구분코드_중분류     object
# 표준산업구분코드_소분류     object
# 종목시가              int64
# 종목고가              int64
# 종목저가              int64
# 종목종가              int64
# 거래량               int64
# 거래금액_만원단위         int64
# dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286061 entries, 0 to 286060
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          286061 non-null  int64
#  1   기준일자           286061 non-null  int64
#  2   종목번호           286061 non-null  object
#  3   종목명            286061 non-null  object
#  4   20년7월TOP3대상여부  286061 non-null  object
#  5   시장구분           286061 non-null  object
#  6   표준산업구분코드_대분류   286061 non-null  object
#  7   표준산업구분코드_중분류   286061 non-null  object
# ...

# %%
gr_trd.head(2)
# Out:
#       index    기준년월   그룹번호  그룹내고객수     종목번호 그룹내_매수여부 그룹내_매도여부  매수고객수  매도고객수  \
# 0         0  201907  MAD01     288  A000660        Y        Y      7     17
# 1         1  201907  MAD01     288  A001820        Y        Y      3      4
# 12       12  201907  MAD02     112  A006800        Y        Y      3      3
# 13       13  201907  MAD02     112  A035420        N        Y      0      3
# 15       15  201907  MAD03     250  A002140        Y        Y      3      3
# 16       16  201907  MAD03     250  A005290        Y        Y      6      5
# 49       49  201907  MAD04     776  A000100        Y        Y      8      4
# 50       50  201907  MAD04     776  A000660        Y        Y     23     36
# 120     120  201907  MAD05     890  A000100        Y        Y      4      3
# 121     121  201907  MAD05     890  A000660        Y        Y      3     11
# 187     187  201907  MAD06    1615  A000080        Y        Y      3      6
# ...

# %%
# print(trd.duplicated().sum())
# print('\n')
# print(trd.isnull().sum())

# print('\n')
# print(sts.duplicated().sum())
# print('\n')
# print(sts.isnull().sum())


############새로운 트레이딩 테이블 생성#################
# list_grname = list(set(np.array(trd['그룹번호'].tolist())))
# list_grname # 그룹번호 리스트1


# # df_grname = pd.DataFrame(data = list_grname, index=range(0,48), columns=['그룹번호 리스트'])

# for i in list_grname
#     for j in 
#     if i == 
# df_grname
# # df_grname

fil_trd = trd.filter(['그룹번호', '종목번호'])
fil_trd

# list1 = list(trd.columns)
# list1
# trd.shape
# Out:
#         그룹번호     종목번호
# 0      MAD01  A000660
# 1      MAD01  A001820
# 2      MAD01  A004020
# 3      MAD01  A005380
# 4      MAD01  A005930
# ...      ...      ...
# 30195  MAD48  A207940
# 30196  MAD48  A272210
# 30197  MAD48  A285130
# 30198  MAD48  A316140
# 30199  MAD48  A336260
#
# [30200 rows x 2 columns]

# %%
df = pd.DataFrame(columns=['내용'])

list1=[]

for i in range(3):
  for j in range(13):
      
      print(trd.iloc[i,j])
  print('\n')
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-4b896ed74441> in <module>()
#       6   for j in range(13):
#       7
# ----> 8       print(list(np.array(trd.iloc[i,j])))
#       9   print('\n')
#      10 list1
#
# TypeError: iteration over a 0-d array
